# %% [markdown]
# # Seaquest DQN — Exp 2: exp2_lr_bump
# **1M steps from scratch** | CnnPolicy | ALE/Seaquest-v5

# %%
import subprocess, sys
for pkg in ['ale-py', 'gymnasium[atari]', 'stable-baselines3', 'opencv-python']:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pkg])
print('All packages installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 5.5 MB/s eta 0:00:00
# All packages installed.

# %%
import os, csv, gc
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import ale_py
import torch
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnNoModelImprovement
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# 2026-03-21 16:13:24.319255: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774109604.557700      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774109604.619247      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774109605.144865      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774109605.144899      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774109605.144902      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774109605.144905      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# CUDA available: True
# GPU: Tesla T4

# %%
EXP_ID = 2
EXP_NAME = 'exp2_lr_bump'
LR = 0.0002
GAMMA = 0.94
BATCH_SIZE = 64
EPS_START = 1.0
EPS_END = 0.05
EPS_FRAC = 0.10
NOTES = 'Slight lr bump — faster policy updates'

ENV_ID = 'ALE/Seaquest-v5'
TOTAL_TIMESTEPS = 1_000_000
BUFFER_SIZE = 50_000
LEARNING_STARTS = 10_000
TARGET_UPDATE = 1_000
N_STACK = 4
OUTPUT_DIR = f'/kaggle/working/kerie/runs/{EXP_NAME}'

print(f'Exp {EXP_ID}: {EXP_NAME}')
print(f'Steps: {TOTAL_TIMESTEPS:,}')
print(f'lr={LR} gamma={GAMMA} batch={BATCH_SIZE}')
print(f'eps: {EPS_START} -> {EPS_END} over {EPS_FRAC} of training')
# Out:
# Exp 2: exp2_lr_bump
# Steps: 1,000,000
# lr=0.0002 gamma=0.94 batch=64
# eps: 1.0 -> 0.05 over 0.1 of training

# %%
def make_env(render_mode=None):
    def _init():
        env = gym.make(ENV_ID, render_mode=render_mode)
        env = AtariWrapper(env)
        return env
    vec_env = DummyVecEnv([_init])
    vec_env = VecFrameStack(vec_env, n_stack=N_STACK)
    return vec_env

log_dir = os.path.join(OUTPUT_DIR, 'tensorboard')
eval_dir = os.path.join(OUTPUT_DIR, 'eval')
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

train_env = make_env()
eval_env = make_env()

# optimize_memory_usage: avoids storing next_state twice in replay buffer (~50% less RAM)
# handle_timeout_termination=False required when optimize_memory_usage=True
# Safe for Atari — AtariWrapper handles episode boundaries via life-loss detection
model = DQN(
    policy='CnnPolicy',
    env=train_env,
    learning_rate=LR,
    gamma=GAMMA,
    batch_size=BATCH_SIZE,
    exploration_initial_eps=EPS_START,
    exploration_final_eps=EPS_END,
    exploration_fraction=EPS_FRAC,
    buffer_size=BUFFER_SIZE,
    learning_starts=LEARNING_STARTS,
    target_update_interval=TARGET_UPDATE,
    tensorboard_log=log_dir,
    verbose=1,
    optimize_memory_usage=True,
    replay_buffer_kwargs={'handle_timeout_termination': False},
)

early_stop = StopTrainingOnNoModelImprovement(max_no_improvement_evals=3, verbose=1)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=eval_dir,
    log_path=eval_dir,
    eval_freq=25_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False,
    callback_after_eval=early_stop,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=eval_callback,
    tb_log_name=EXP_NAME,
    reset_num_timesteps=True,
)

model.save(os.path.join(OUTPUT_DIR, 'dqn_model'))
print(f'\nModel saved -> {OUTPUT_DIR}/dqn_model.zip')

train_env.close()
eval_env.close()
del model
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to /kaggle/working/kerie/runs/exp2_lr_bump/tensorboard/exp2_lr_bump_1
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x
|
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00367  |
# |    n_updates        | 989      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 267      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 14034    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00649  |
# |    n_updates        | 1008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 266      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 14111    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0329   |
# |    n_updates        | 1027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 266      |
# ...
# |    fps              | 180      |
# |    time_elapsed     | 2286     |
# |    total_timesteps  | 411929   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0194   |
# |    n_updates        | 100482   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6032     |
# |    fps              | 180      |
# |    time_elapsed     | 2288     |
# |    total_timesteps  | 412415   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0488   |
# |    n_updates        | 100603   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6036     |
# |    fps              | 180      |
# |    time_elapsed     | 2290     |
# |    total_timesteps  | 412671   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0171   |
# |    n_updates        | 100667   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6040     |
# |    fps              | 180      |
# |    time_elapsed     | 2293     |
# |    total_timesteps  | 413186   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0309   |
# |    n_updates        | 100796   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6044     |
# |    fps              | 180      |
# |    time_elapsed     | 2294     |
# |    total_timesteps  | 413484   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0147   |
# |    n_updates        | 100870   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6048     |
# |    fps              | 180      |
# |    time_elapsed     | 2297     |
# |    total_timesteps  | 413920   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0253   |
# |    n_updates        | 100979   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6052     |
# |    fps              | 180      |
# |    time_elapsed     | 2299     |
# |    total_timesteps  | 414354   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0253   |
# |    n_updates        | 101088   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6056     |
# |    fps              | 180      |
# |    time_elapsed     | 2301     |
# |    total_timesteps  | 414781   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0227   |
# |    n_updates        | 101195   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6060     |
# |    fps              | 180      |
# |    time_elapsed     | 2303     |
# |    total_timesteps  | 415172   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0258   |
# |    n_updates        | 101292   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6064     |
# |    fps              | 180      |
# |    time_elapsed     | 2306     |
# |    total_timesteps  | 415578   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.02     |
# |    n_updates        | 101394   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6068     |
# |    fps              | 180      |
# |    time_elapsed     | 2307     |
# |    total_timesteps  | 415873   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0417   |
# |    n_updates        | 101468   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6072     |
# |    fps              | 180      |
# |    time_elapsed     | 2309     |
# |    total_timesteps  | 416230   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0266   |
# |    n_updates        | 101557   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6076     |
# |    fps              | 180      |
# |    time_elapsed     | 2312     |
# |    total_timesteps  | 416743   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0287   |
# |    n_updates        | 101685   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6080     |
# |    fps              | 180      |
# |    time_elapsed     | 2314     |
# |    total_timesteps  | 417117   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.022    |
# |    n_updates        | 101779   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6084     |
# |    fps              | 180      |
# |    time_elapsed     | 2317     |
# |    total_timesteps  | 417560   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0379   |
# |    n_updates        | 101889   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6088     |
# |    fps              | 180      |
# |    time_elapsed     | 2319     |
# |    total_timesteps  | 417964   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0158   |
# |    n_updates        | 101990   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6092     |
# |    fps              | 180      |
# |    time_elapsed     | 2321     |
# |    total_timesteps  | 418290   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0231   |
# |    n_updates        | 102072   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6096     |
# |    fps              | 180      |
# |    time_elapsed     | 2323     |
# |    total_timesteps  | 418742   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0185   |
# |    n_updates        | 102185   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6100     |
# |    fps              | 180      |
# |    time_elapsed     | 2325     |
# |    total_timesteps  | 419007   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0332   |
# |    n_updates        | 102251   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6104     |
# |    fps              | 180      |
# |    time_elapsed     | 2327     |
# |    total_timesteps  | 419480   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0225   |
# |    n_updates        | 102369   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6108     |
# |    fps              | 180      |
# |    time_elapsed     | 2330     |
# |    total_timesteps  | 420009   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.018    |
# |    n_updates        | 102502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6112     |
# |    fps              | 180      |
# |    time_elapsed     | 2332     |
# |    total_timesteps  | 420391   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0174   |
# |    n_updates        | 102597   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6116     |
# |    fps              | 180      |
# |    time_elapsed     | 2334     |
# |    total_timesteps  | 420743   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0263   |
# |    n_updates        | 102685   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6120     |
# |    fps              | 180      |
# |    time_elapsed     | 2337     |
# |    total_timesteps  | 421162   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0311   |
# |    n_updates        | 102790   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6124     |
# |    fps              | 180      |
# |    time_elapsed     | 2339     |
# |    total_timesteps  | 421559   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0325   |
# |    n_updates        | 102889   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6128     |
# |    fps              | 180      |
# |    time_elapsed     | 2341     |
# |    total_timesteps  | 421955   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0237   |
# |    n_updates        | 102988   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6132     |
# |    fps              | 180      |
# |    time_elapsed     | 2343     |
# |    total_timesteps  | 422287   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0195   |
# |    n_updates        | 103071   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6136     |
# |    fps              | 180      |
# |    time_elapsed     | 2346     |
# |    total_timesteps  | 422825   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0159   |
# |    n_updates        | 103206   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6140     |
# |    fps              | 180      |
# |    time_elapsed     | 2348     |
# |    total_timesteps  | 423259   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0247   |
# |    n_updates        | 103314   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6144     |
# |    fps              | 180      |
# |    time_elapsed     | 2350     |
# |    total_timesteps  | 423543   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0184   |
# |    n_updates        | 103385   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6148     |
# |    fps              | 180      |
# |    time_elapsed     | 2352     |
# |    total_timesteps  | 423890   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0232   |
# |    n_updates        | 103472   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6152     |
# |    fps              | 180      |
# |    time_elapsed     | 2354     |
# |    total_timesteps  | 424240   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0261   |
# |    n_updates        | 103559   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6156     |
# |    fps              | 180      |
# |    time_elapsed     | 2356     |
# |    total_timesteps  | 424645   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0181   |
# |    n_updates        | 103661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6160     |
# |    fps              | 180      |
# |    time_elapsed     | 2358     |
# |    total_timesteps  | 424931   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0548   |
# |    n_updates        | 103732   |
# ----------------------------------
# Eval num_timesteps=425000, episode_reward=21.00 +/- 5.10
# Episode length: 123.20 +/- 24.84
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 123      |
# |    mean_reward      | 21       |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 425000   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0506   |
# |    n_updates        | 103749   |
# ----------------------------------
# Stopping training because there was no new best model in the last 4 evaluations
#
# Model saved -> /kaggle/working/kerie/runs/exp2_lr_bump/dqn_model.zip

# %%
eval_npz = os.path.join(eval_dir, 'evaluations.npz')
if os.path.isfile(eval_npz):
    data = np.load(eval_npz)
    timesteps = data['timesteps']
    mean_rewards = data['results'].mean(axis=1)
    std_rewards = data['results'].std(axis=1)

    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, mean_rewards, label='Mean Reward')
    plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3, label='Std Dev')
    plt.xlabel('Timesteps')
    plt.ylabel('Eval Reward')
    plt.title(f'Exp {EXP_ID:02d}: {EXP_NAME}\nlr={LR} gamma={GAMMA} batch={BATCH_SIZE} eps_frac={EPS_FRAC}')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'reward_plot.png'), dpi=150)
    plt.show()

    csv_path = os.path.join(OUTPUT_DIR, 'results.csv')
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['timestep', 'mean_reward', 'std_reward'])
        for t, m, s in zip(timesteps, mean_rewards, std_rewards):
            writer.writerow([int(t), f'{m:.2f}', f'{s:.2f}'])

    print(f'Best reward: {mean_rewards.max():.1f}')
    print(f'Final reward: {mean_rewards[-1]:.1f}')
    print(f'\nDownload outputs from the Output tab ->')
# Out:
# Best reward: 21.6
# Final reward: 21.0
#
# Download outputs from the Output tab ->
