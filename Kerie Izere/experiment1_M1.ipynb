# %% [markdown]
# # Seaquest DQN — Exp 1: exp1_baseline_mid
# **1M steps from scratch** | CnnPolicy | ALE/Seaquest-v5

# %%
import subprocess, sys
for pkg in ['ale-py', 'gymnasium[atari]', 'stable-baselines3', 'opencv-python']:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pkg])
print('All packages installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 4.3 MB/s eta 0:00:00
# All packages installed.

# %%
import os, csv, gc
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import ale_py
import torch
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnNoModelImprovement
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# 2026-03-20 23:59:59.730982: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774051199.926667      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774051199.978647      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774051200.412355      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774051200.412394      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774051200.412396      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774051200.412399      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# CUDA available: True
# GPU: Tesla P100-PCIE-16GB
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
EXP_ID = 1
EXP_NAME = 'exp1_baseline_mid'
LR = 0.0001
GAMMA = 0.94
BATCH_SIZE = 64
EPS_START = 1.0
EPS_END = 0.05
EPS_FRAC = 0.10
NOTES = 'Baseline mid — good balance'

ENV_ID = 'ALE/Seaquest-v5'
TOTAL_TIMESTEPS = 1_000_000
BUFFER_SIZE = 50_000
LEARNING_STARTS = 10_000
TARGET_UPDATE = 1_000
N_STACK = 4
OUTPUT_DIR = f'/kaggle/working/kerie/runs/{EXP_NAME}'

print(f'Exp {EXP_ID}: {EXP_NAME}')
print(f'Steps: {TOTAL_TIMESTEPS:,}')
print(f'lr={LR} gamma={GAMMA} batch={BATCH_SIZE}')
print(f'eps: {EPS_START} -> {EPS_END} over {EPS_FRAC} of training')
# Out:
# Exp 1: exp1_baseline_mid
# Steps: 1,000,000
# lr=0.0001 gamma=0.94 batch=64
# eps: 1.0 -> 0.05 over 0.1 of training

# %%
def make_env(render_mode=None):
    def _init():
        env = gym.make(ENV_ID, render_mode=render_mode)
        env = AtariWrapper(env)
        return env
    vec_env = DummyVecEnv([_init])
    vec_env = VecFrameStack(vec_env, n_stack=N_STACK)
    return vec_env

log_dir = os.path.join(OUTPUT_DIR, 'tensorboard')
eval_dir = os.path.join(OUTPUT_DIR, 'eval')
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

train_env = make_env()
eval_env = make_env()

# optimize_memory_usage: avoids storing next_state twice in replay buffer (~50% less RAM)
# handle_timeout_termination=False required when optimize_memory_usage=True
# Safe for Atari — AtariWrapper handles episode boundaries via life-loss detection
model = DQN(
    policy='CnnPolicy',
    env=train_env,
    learning_rate=LR,
    gamma=GAMMA,
    batch_size=BATCH_SIZE,
    exploration_initial_eps=EPS_START,
    exploration_final_eps=EPS_END,
    exploration_fraction=EPS_FRAC,
    buffer_size=BUFFER_SIZE,
    learning_starts=LEARNING_STARTS,
    target_update_interval=TARGET_UPDATE,
    tensorboard_log=log_dir,
    verbose=1,
    optimize_memory_usage=True,
    replay_buffer_kwargs={'handle_timeout_termination': False},
)

early_stop = StopTrainingOnNoModelImprovement(max_no_improvement_evals=3, verbose=1)
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=eval_dir,
    log_path=eval_dir,
    eval_freq=25_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False,
    callback_after_eval=early_stop,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=eval_callback,
    tb_log_name=EXP_NAME,
    reset_num_timesteps=True,
)

model.save(os.path.join(OUTPUT_DIR, 'dqn_model'))
print(f'\nModel saved -> {OUTPUT_DIR}/dqn_model.zip')

train_env.close()
eval_env.close()
del model
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 850      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 283      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 13488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 871      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 282      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 13632    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 907      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 282      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 13728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00298  |
# ...
# |    fps              | 200      |
# |    time_elapsed     | 1809     |
# |    total_timesteps  | 362556   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 88138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5928     |
# |    fps              | 200      |
# |    time_elapsed     | 1812     |
# |    total_timesteps  | 363039   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 88259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5932     |
# |    fps              | 200      |
# |    time_elapsed     | 1814     |
# |    total_timesteps  | 363559   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 88389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5936     |
# |    fps              | 200      |
# |    time_elapsed     | 1816     |
# |    total_timesteps  | 363895   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 88473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5940     |
# |    fps              | 200      |
# |    time_elapsed     | 1818     |
# |    total_timesteps  | 364350   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 88587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5944     |
# |    fps              | 200      |
# |    time_elapsed     | 1820     |
# |    total_timesteps  | 364644   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 88660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5948     |
# |    fps              | 200      |
# |    time_elapsed     | 1821     |
# |    total_timesteps  | 364956   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0651   |
# |    n_updates        | 88738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5952     |
# |    fps              | 200      |
# |    time_elapsed     | 1823     |
# |    total_timesteps  | 365185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0658   |
# |    n_updates        | 88796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5956     |
# |    fps              | 200      |
# |    time_elapsed     | 1824     |
# |    total_timesteps  | 365498   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 88874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5960     |
# |    fps              | 200      |
# |    time_elapsed     | 1826     |
# |    total_timesteps  | 365890   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 88972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5964     |
# |    fps              | 200      |
# |    time_elapsed     | 1829     |
# |    total_timesteps  | 366356   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0768   |
# |    n_updates        | 89088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5968     |
# |    fps              | 200      |
# |    time_elapsed     | 1831     |
# |    total_timesteps  | 366699   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 89174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5972     |
# |    fps              | 200      |
# |    time_elapsed     | 1833     |
# |    total_timesteps  | 367095   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 89273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5976     |
# |    fps              | 200      |
# |    time_elapsed     | 1835     |
# |    total_timesteps  | 367487   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0821   |
# |    n_updates        | 89371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5980     |
# |    fps              | 200      |
# |    time_elapsed     | 1836     |
# |    total_timesteps  | 367846   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0397   |
# |    n_updates        | 89461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5984     |
# |    fps              | 200      |
# |    time_elapsed     | 1839     |
# |    total_timesteps  | 368262   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 89565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5988     |
# |    fps              | 200      |
# |    time_elapsed     | 1839     |
# |    total_timesteps  | 368451   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.039    |
# |    n_updates        | 89612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5992     |
# |    fps              | 200      |
# |    time_elapsed     | 1842     |
# |    total_timesteps  | 368908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0671   |
# |    n_updates        | 89726    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5996     |
# |    fps              | 200      |
# |    time_elapsed     | 1844     |
# |    total_timesteps  | 369349   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.059    |
# |    n_updates        | 89837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6000     |
# |    fps              | 200      |
# |    time_elapsed     | 1846     |
# |    total_timesteps  | 369746   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 89936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6004     |
# |    fps              | 200      |
# |    time_elapsed     | 1847     |
# |    total_timesteps  | 370026   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0364   |
# |    n_updates        | 90006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6008     |
# |    fps              | 200      |
# |    time_elapsed     | 1849     |
# |    total_timesteps  | 370397   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 90099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6012     |
# |    fps              | 200      |
# |    time_elapsed     | 1852     |
# |    total_timesteps  | 370870   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 90217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6016     |
# |    fps              | 200      |
# |    time_elapsed     | 1853     |
# |    total_timesteps  | 371203   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0695   |
# |    n_updates        | 90300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6020     |
# |    fps              | 200      |
# |    time_elapsed     | 1855     |
# |    total_timesteps  | 371516   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0329   |
# |    n_updates        | 90378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6024     |
# |    fps              | 200      |
# |    time_elapsed     | 1857     |
# |    total_timesteps  | 371963   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 90490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6028     |
# |    fps              | 200      |
# |    time_elapsed     | 1859     |
# |    total_timesteps  | 372320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 90579    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6032     |
# |    fps              | 200      |
# |    time_elapsed     | 1861     |
# |    total_timesteps  | 372645   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 90661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6036     |
# |    fps              | 200      |
# |    time_elapsed     | 1863     |
# |    total_timesteps  | 373002   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0816   |
# |    n_updates        | 90750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6040     |
# |    fps              | 200      |
# |    time_elapsed     | 1865     |
# |    total_timesteps  | 373461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0444   |
# |    n_updates        | 90865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6044     |
# |    fps              | 200      |
# |    time_elapsed     | 1867     |
# |    total_timesteps  | 373806   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0324   |
# |    n_updates        | 90951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6048     |
# |    fps              | 200      |
# |    time_elapsed     | 1868     |
# |    total_timesteps  | 374025   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0577   |
# |    n_updates        | 91006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6052     |
# |    fps              | 200      |
# |    time_elapsed     | 1870     |
# |    total_timesteps  | 374443   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0324   |
# |    n_updates        | 91110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6056     |
# |    fps              | 200      |
# |    time_elapsed     | 1872     |
# |    total_timesteps  | 374934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 91233    |
# ----------------------------------
# Eval num_timesteps=375000, episode_reward=17.20 +/- 9.13
# Episode length: 93.60 +/- 41.95
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 93.6     |
# |    mean_reward      | 17.2     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 375000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0722   |
# |    n_updates        | 91249    |
# ----------------------------------
# Stopping training because there was no new best model in the last 4 evaluations
#
# Model saved -> /kaggle/working/kerie/runs/exp1_baseline_mid/dqn_model.zip

# %%
eval_npz = os.path.join(eval_dir, 'evaluations.npz')
if os.path.isfile(eval_npz):
    data = np.load(eval_npz)
    timesteps = data['timesteps']
    mean_rewards = data['results'].mean(axis=1)
    std_rewards = data['results'].std(axis=1)

    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, mean_rewards, label='Mean Reward')
    plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3, label='Std Dev')
    plt.xlabel('Timesteps')
    plt.ylabel('Eval Reward')
    plt.title(f'Exp {EXP_ID:02d}: {EXP_NAME}\nlr={LR} gamma={GAMMA} batch={BATCH_SIZE} eps_frac={EPS_FRAC}')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'reward_plot.png'), dpi=150)
    plt.show()

    csv_path = os.path.join(OUTPUT_DIR, 'results.csv')
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['timestep', 'mean_reward', 'std_reward'])
        for t, m, s in zip(timesteps, mean_rewards, std_rewards):
            writer.writerow([int(t), f'{m:.2f}', f'{s:.2f}'])

    print(f'Best reward: {mean_rewards.max():.1f}')
    print(f'Final reward: {mean_rewards[-1]:.1f}')
    print(f'\nDownload outputs from the Output tab ->')
# Out:
# Best reward: 20.8
# Final reward: 17.2
#
# Download outputs from the Output tab ->
