# %% [markdown]
# # Seaquest DQN — Exp 3: exp3_higher_gamma
# **1M steps from scratch** | CnnPolicy | ALE/Seaquest-v5

# %%
import subprocess, sys

# Reinstall PyTorch with correct CUDA version for this Kaggle GPU
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
    'torch', 'torchvision', '--index-url', 'https://download.pytorch.org/whl/cu121'])

for pkg in ['ale-py', 'gymnasium[atari]', 'stable-baselines3', 'opencv-python']:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pkg])
print('All packages installed.')
# Out:
# All packages installed.

# %%
import os, csv, gc
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import ale_py
import torch
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import EvalCallback
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
EXP_ID = 3
EXP_NAME = 'exp3_higher_gamma'
LR = 0.0001
GAMMA = 0.95
BATCH_SIZE = 64
EPS_START = 1.0
EPS_END = 0.05
EPS_FRAC = 0.10
NOTES = 'Higher gamma — values future rewards more'

ENV_ID = 'ALE/Seaquest-v5'
TOTAL_TIMESTEPS = 1_000_000
BUFFER_SIZE = 50_000
LEARNING_STARTS = 10_000
TARGET_UPDATE = 1_000
N_STACK = 4
OUTPUT_DIR = f'/kaggle/working/kerie/runs/{EXP_NAME}'

print(f'Exp {EXP_ID}: {EXP_NAME}')
print(f'Steps: {TOTAL_TIMESTEPS:,}')
print(f'lr={LR} gamma={GAMMA} batch={BATCH_SIZE}')
print(f'eps: {EPS_START} -> {EPS_END} over {EPS_FRAC} of training')
# Out:
# Exp 3: exp3_higher_gamma
# Steps: 1,000,000
# lr=0.0001 gamma=0.95 batch=64
# eps: 1.0 -> 0.05 over 0.1 of training

# %%
def make_env(render_mode=None):
    def _init():
        env = gym.make(ENV_ID, render_mode=render_mode)
        env = AtariWrapper(env)
        return env
    vec_env = DummyVecEnv([_init])
    vec_env = VecFrameStack(vec_env, n_stack=N_STACK)
    return vec_env

log_dir = os.path.join(OUTPUT_DIR, 'tensorboard')
eval_dir = os.path.join(OUTPUT_DIR, 'eval')
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

train_env = make_env()
eval_env = make_env()

# optimize_memory_usage: avoids storing next_state twice in replay buffer (~50% less RAM)
# handle_timeout_termination=False required when optimize_memory_usage=True
# Safe for Atari — AtariWrapper handles episode boundaries via life-loss detection
model = DQN(
    policy='CnnPolicy',
    env=train_env,
    learning_rate=LR,
    gamma=GAMMA,
    batch_size=BATCH_SIZE,
    exploration_initial_eps=EPS_START,
    exploration_final_eps=EPS_END,
    exploration_fraction=EPS_FRAC,
    buffer_size=BUFFER_SIZE,
    learning_starts=LEARNING_STARTS,
    target_update_interval=TARGET_UPDATE,
    tensorboard_log=log_dir,
    verbose=1,
    optimize_memory_usage=True,
    replay_buffer_kwargs={'handle_timeout_termination': False},
)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=eval_dir,
    log_path=eval_dir,
    eval_freq=25_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=eval_callback,
    tb_log_name=EXP_NAME,
    reset_num_timesteps=True,
)

model.save(os.path.join(OUTPUT_DIR, 'dqn_model'))
print(f'\nModel saved -> {OUTPUT_DIR}/dqn_model.zip')

train_env.close()
eval_env.close()
del model
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to /kaggle/working/kerie/runs/exp3_higher_gamma/tensorboard/exp3_higher_gamma_1
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7abe4e705820> != <stable_baselines3.common.vec_env.vec_frame_stack.VecFrameStack object at 0x7abe4e774f50>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 271      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 111      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 280      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 282      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 295      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 289      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 405      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 291      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 294      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 607      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 293      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 759      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 293      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 293      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 944      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 295      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 295      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 294      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 295      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 295      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 296      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1611     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 295      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 296      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 296      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1897     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 296      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 296      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 296      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 296      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2376     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 296      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 296      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 296      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 296      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 296      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 296      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 295      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 2975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 296      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 296      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3177     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 296      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3273     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 297      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3452     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 296      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 296      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 297      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 297      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 297      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3985     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 297      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 4052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 297      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 4125     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 296      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 296      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4303     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 296      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 297      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 297      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 297      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 297      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 4801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 296      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 4884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 297      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 5020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 297      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 5122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 296      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 5216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 296      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 5285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 296      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 296      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 296      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 296      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 5705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 296      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 5780     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 296      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 5883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 296      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 5947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 296      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 6082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 297      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 6196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 297      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 297      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 297      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 297      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 297      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 297      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 297      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 297      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 297      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 7044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 297      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 7154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 297      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 7246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 297      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 7344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 297      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 297      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7534     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 297      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 297      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 297      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7836     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 297      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7958     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 297      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 8041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 297      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 8141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 297      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 8231     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 297      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 297      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8387     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 297      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8483     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 297      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8611     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 297      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8697     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 297      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 297      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8877     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 297      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 297      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 9079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 296      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 9145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 296      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9214     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 296      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 296      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 296      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 296      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9524     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 296      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 296      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 296      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9754     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 296      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 9856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 296      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 9972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 295      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 10055    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 294      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 10144    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 35       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 293      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 10240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 59       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 291      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 10382    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00699  |
# |    n_updates        | 95       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 290      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 10485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 121      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 289      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 10554    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 138      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 288      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 10656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 163      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 286      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 10824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.016    |
# |    n_updates        | 205      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 285      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 10909    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 227      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 284      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 10975    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000342 |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 283      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 11035    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 258      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 282      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 11114    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 278      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 281      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 11203    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000733 |
# |    n_updates        | 300      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 280      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 11340    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000756 |
# |    n_updates        | 334      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 279      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 11446    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000525 |
# |    n_updates        | 361      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 278      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 11614    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 403      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 277      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 11714    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 428      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 276      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 11807    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00809  |
# |    n_updates        | 451      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 275      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 11920    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 479      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 274      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 12009    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 502      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 273      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 12118    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00788  |
# |    n_updates        | 529      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 272      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 12183    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00145  |
# |    n_updates        | 545      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 272      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 12275    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00809  |
# |    n_updates        | 568      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 271      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 12413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 603      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 270      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 12499    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00485  |
# |    n_updates        | 624      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 269      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 12589    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 647      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 268      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 12673    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 668      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 267      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 12775    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00736  |
# |    n_updates        | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 267      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 12851    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 712      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 266      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 12972    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 742      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 265      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 13109    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 777      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 264      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 13233    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00885  |
# |    n_updates        | 808      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 264      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 13334    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 833      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 263      |
# |    time_elapsed     | 50       |
# ...
# | time/               |          |
# |    episodes         | 11064    |
# |    fps              | 170      |
# |    time_elapsed     | 5770     |
# |    total_timesteps  | 983943   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.141    |
# |    n_updates        | 243485   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11068    |
# |    fps              | 170      |
# |    time_elapsed     | 5774     |
# |    total_timesteps  | 984540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0536   |
# |    n_updates        | 243634   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11072    |
# |    fps              | 170      |
# |    time_elapsed     | 5776     |
# |    total_timesteps  | 984980   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 243744   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11076    |
# |    fps              | 170      |
# |    time_elapsed     | 5780     |
# |    total_timesteps  | 985512   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0737   |
# |    n_updates        | 243877   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11080    |
# |    fps              | 170      |
# |    time_elapsed     | 5782     |
# |    total_timesteps  | 985915   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 243978   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11084    |
# |    fps              | 170      |
# |    time_elapsed     | 5785     |
# |    total_timesteps  | 986313   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0901   |
# |    n_updates        | 244078   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11088    |
# |    fps              | 170      |
# |    time_elapsed     | 5786     |
# |    total_timesteps  | 986613   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 244153   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11092    |
# |    fps              | 170      |
# |    time_elapsed     | 5788     |
# |    total_timesteps  | 986907   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0373   |
# |    n_updates        | 244226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11096    |
# |    fps              | 170      |
# |    time_elapsed     | 5791     |
# |    total_timesteps  | 987394   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0849   |
# |    n_updates        | 244348   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11100    |
# |    fps              | 170      |
# |    time_elapsed     | 5794     |
# |    total_timesteps  | 987791   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0494   |
# |    n_updates        | 244447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11104    |
# |    fps              | 170      |
# |    time_elapsed     | 5796     |
# |    total_timesteps  | 988185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.133    |
# |    n_updates        | 244546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11108    |
# |    fps              | 170      |
# |    time_elapsed     | 5799     |
# |    total_timesteps  | 988660   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0532   |
# |    n_updates        | 244664   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11112    |
# |    fps              | 170      |
# |    time_elapsed     | 5802     |
# |    total_timesteps  | 989066   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0496   |
# |    n_updates        | 244766   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11116    |
# |    fps              | 170      |
# |    time_elapsed     | 5805     |
# |    total_timesteps  | 989681   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 244920   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11120    |
# |    fps              | 170      |
# |    time_elapsed     | 5808     |
# |    total_timesteps  | 990074   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0265   |
# |    n_updates        | 245018   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11124    |
# |    fps              | 170      |
# |    time_elapsed     | 5811     |
# |    total_timesteps  | 990565   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0432   |
# |    n_updates        | 245141   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11128    |
# |    fps              | 170      |
# |    time_elapsed     | 5814     |
# |    total_timesteps  | 991114   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0593   |
# |    n_updates        | 245278   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11132    |
# |    fps              | 170      |
# |    time_elapsed     | 5817     |
# |    total_timesteps  | 991567   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0481   |
# |    n_updates        | 245391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11136    |
# |    fps              | 170      |
# |    time_elapsed     | 5820     |
# |    total_timesteps  | 992099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0752   |
# |    n_updates        | 245524   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11140    |
# |    fps              | 170      |
# |    time_elapsed     | 5824     |
# |    total_timesteps  | 992715   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 245678   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11144    |
# |    fps              | 170      |
# |    time_elapsed     | 5828     |
# |    total_timesteps  | 993283   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0431   |
# |    n_updates        | 245820   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11148    |
# |    fps              | 170      |
# |    time_elapsed     | 5831     |
# |    total_timesteps  | 993817   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0959   |
# |    n_updates        | 245954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11152    |
# |    fps              | 170      |
# |    time_elapsed     | 5836     |
# |    total_timesteps  | 994589   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0942   |
# |    n_updates        | 246147   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11156    |
# |    fps              | 170      |
# |    time_elapsed     | 5839     |
# |    total_timesteps  | 995144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 246285   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11160    |
# |    fps              | 170      |
# |    time_elapsed     | 5842     |
# |    total_timesteps  | 995705   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0677   |
# |    n_updates        | 246426   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11164    |
# |    fps              | 170      |
# |    time_elapsed     | 5845     |
# |    total_timesteps  | 996038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.044    |
# |    n_updates        | 246509   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11168    |
# |    fps              | 170      |
# |    time_elapsed     | 5848     |
# |    total_timesteps  | 996556   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 246638   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11172    |
# |    fps              | 170      |
# |    time_elapsed     | 5850     |
# |    total_timesteps  | 996880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0395   |
# |    n_updates        | 246719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11176    |
# |    fps              | 170      |
# |    time_elapsed     | 5853     |
# |    total_timesteps  | 997432   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0905   |
# |    n_updates        | 246857   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11180    |
# |    fps              | 170      |
# |    time_elapsed     | 5855     |
# |    total_timesteps  | 997737   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0502   |
# |    n_updates        | 246934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11184    |
# |    fps              | 170      |
# |    time_elapsed     | 5858     |
# |    total_timesteps  | 998331   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 247082   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11188    |
# |    fps              | 170      |
# |    time_elapsed     | 5862     |
# |    total_timesteps  | 998992   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 247247   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11192    |
# |    fps              | 170      |
# |    time_elapsed     | 5865     |
# |    total_timesteps  | 999370   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.117    |
# |    n_updates        | 247342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11196    |
# |    fps              | 170      |
# |    time_elapsed     | 5868     |
# |    total_timesteps  | 999981   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0509   |
# |    n_updates        | 247495   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=44.40 +/- 21.97
# Episode length: 158.00 +/- 79.89
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 158      |
# |    mean_reward      | 44.4     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 247499   |
# ----------------------------------
#
# Model saved -> /kaggle/working/kerie/runs/exp3_higher_gamma/dqn_model.zip

# %%
eval_npz = os.path.join(eval_dir, 'evaluations.npz')
if os.path.isfile(eval_npz):
    data = np.load(eval_npz)
    timesteps = data['timesteps']
    mean_rewards = data['results'].mean(axis=1)
    std_rewards = data['results'].std(axis=1)

    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, mean_rewards, label='Mean Reward')
    plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3, label='Std Dev')
    plt.xlabel('Timesteps')
    plt.ylabel('Eval Reward')
    plt.title(f'Exp {EXP_ID:02d}: {EXP_NAME}\nlr={LR} gamma={GAMMA} batch={BATCH_SIZE} eps_frac={EPS_FRAC}')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'reward_plot.png'), dpi=150)
    plt.show()

    csv_path = os.path.join(OUTPUT_DIR, 'results.csv')
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['timestep', 'mean_reward', 'std_reward'])
        for t, m, s in zip(timesteps, mean_rewards, std_rewards):
            writer.writerow([int(t), f'{m:.2f}', f'{s:.2f}'])

    print(f'Best reward: {mean_rewards.max():.1f}')
    print(f'Final reward: {mean_rewards[-1]:.1f}')
    print(f'\nDownload outputs from the Output tab ->')
# Out:
# Best reward: 49.4
# Final reward: 44.4
#
# Download outputs from the Output tab ->

# %%
# !zip -r runs.zip /kaggle/working/kerie/runs
# Out:
# updating: kaggle/working/kerie/runs/exp2_lr_bump/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/tensorboard/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/tensorboard/exp2_lr_bump_1/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/tensorboard/exp2_lr_bump_1/events.out.tfevents.1774109628.014752af350c.55.0 (deflated 76%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/dqn_model.zip (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/reward_plot.png (deflated 8%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/eval/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/eval/evaluations.npz (deflated 72%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/eval/best_model.zip (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/results.csv (deflated 48%)
#   adding: kaggle/working/kerie/runs/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/tensorboard/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/tensorboard/exp3_higher_gamma_1/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/tensorboard/exp3_higher_gamma_1/events.out.tfevents.1774114589.014752af350c.55.1 (deflated 76%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/dqn_model.zip (stored 0%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/reward_plot.png (deflated 7%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/eval/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/eval/evaluations.npz (deflated 74%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/eval/best_model.zip (stored 0%)
#   adding: kaggle/working/kerie/runs/exp3_higher_gamma/results.csv (deflated 58%)
