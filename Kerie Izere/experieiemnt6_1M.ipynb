# %% [markdown]
# # Seaquest DQN — Exp 6: exp6_faster_decay
# **1M steps from scratch** | CnnPolicy | ALE/Seaquest-v5

# %%
import subprocess, sys

# Reinstall PyTorch with correct CUDA version for this Kaggle GPU
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
    'torch', 'torchvision', '--index-url', 'https://download.pytorch.org/whl/cu121'])

for pkg in ['ale-py', 'gymnasium[atari]', 'stable-baselines3', 'opencv-python']:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pkg])
print('All packages installed.')
# Out:
# All packages installed.

# %%
import os, csv, gc
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import ale_py
import torch
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import EvalCallback
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
EXP_ID = 6
EXP_NAME = 'exp6_faster_decay'
LR = 0.0002
GAMMA = 0.95
BATCH_SIZE = 64
EPS_START = 1.0
EPS_END = 0.05
EPS_FRAC = 0.05
NOTES = 'Faster decay — earlier shift to exploit'

ENV_ID = 'ALE/Seaquest-v5'
TOTAL_TIMESTEPS = 1_000_000
BUFFER_SIZE = 50_000
LEARNING_STARTS = 10_000
TARGET_UPDATE = 1_000
N_STACK = 4
OUTPUT_DIR = f'/kaggle/working/kerie/runs/{EXP_NAME}'

print(f'Exp {EXP_ID}: {EXP_NAME}')
print(f'Steps: {TOTAL_TIMESTEPS:,}')
print(f'lr={LR} gamma={GAMMA} batch={BATCH_SIZE}')
print(f'eps: {EPS_START} -> {EPS_END} over {EPS_FRAC} of training')
# Out:
# Exp 6: exp6_faster_decay
# Steps: 1,000,000
# lr=0.0002 gamma=0.95 batch=64
# eps: 1.0 -> 0.05 over 0.05 of training

# %%
def make_env(render_mode=None):
    def _init():
        env = gym.make(ENV_ID, render_mode=render_mode)
        env = AtariWrapper(env)
        return env
    vec_env = DummyVecEnv([_init])
    vec_env = VecFrameStack(vec_env, n_stack=N_STACK)
    return vec_env

log_dir = os.path.join(OUTPUT_DIR, 'tensorboard')
eval_dir = os.path.join(OUTPUT_DIR, 'eval')
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

train_env = make_env()
eval_env = make_env()

# optimize_memory_usage: avoids storing next_state twice in replay buffer (~50% less RAM)
# handle_timeout_termination=False required when optimize_memory_usage=True
# Safe for Atari — AtariWrapper handles episode boundaries via life-loss detection
model = DQN(
    policy='CnnPolicy',
    env=train_env,
    learning_rate=LR,
    gamma=GAMMA,
    batch_size=BATCH_SIZE,
    exploration_initial_eps=EPS_START,
    exploration_final_eps=EPS_END,
    exploration_fraction=EPS_FRAC,
    buffer_size=BUFFER_SIZE,
    learning_starts=LEARNING_STARTS,
    target_update_interval=TARGET_UPDATE,
    tensorboard_log=log_dir,
    verbose=1,
    optimize_memory_usage=True,
    replay_buffer_kwargs={'handle_timeout_termination': False},
)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=eval_dir,
    log_path=eval_dir,
    eval_freq=25_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=eval_callback,
    tb_log_name=EXP_NAME,
    reset_num_timesteps=True,
)

model.save(os.path.join(OUTPUT_DIR, 'dqn_model'))
print(f'\nModel saved -> {OUTPUT_DIR}/dqn_model.zip')

train_env.close()
eval_env.close()
del model
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to /kaggle/working/kerie/runs/exp6_faster_decay/tensorboard/exp6_faster_decay_1
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7abe4e776690> != <stable_baselines3.common.vec_env.vec_frame_stack.VecFrameStack object at 0x7abe4e779c10>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              |
|
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0253   |
# |    n_updates        | 1046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 249      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 14274    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0163   |
# |    n_updates        | 1068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 249      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 14380    |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.00647  |
# |    n_updates        | 1094     |
# ...
# | time/               |          |
# |    episodes         | 10556    |
# |    fps              | 166      |
# |    time_elapsed     | 5909     |
# |    total_timesteps  | 985235   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0735   |
# |    n_updates        | 243808   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10560    |
# |    fps              | 166      |
# |    time_elapsed     | 5913     |
# |    total_timesteps  | 985739   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0513   |
# |    n_updates        | 243934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10564    |
# |    fps              | 166      |
# |    time_elapsed     | 5914     |
# |    total_timesteps  | 986034   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0271   |
# |    n_updates        | 244008   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10568    |
# |    fps              | 166      |
# |    time_elapsed     | 5918     |
# |    total_timesteps  | 986546   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.102    |
# |    n_updates        | 244136   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10572    |
# |    fps              | 166      |
# |    time_elapsed     | 5919     |
# |    total_timesteps  | 986857   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0328   |
# |    n_updates        | 244214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10576    |
# |    fps              | 166      |
# |    time_elapsed     | 5922     |
# |    total_timesteps  | 987287   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0539   |
# |    n_updates        | 244321   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10580    |
# |    fps              | 166      |
# |    time_elapsed     | 5925     |
# |    total_timesteps  | 987722   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0345   |
# |    n_updates        | 244430   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10584    |
# |    fps              | 166      |
# |    time_elapsed     | 5927     |
# |    total_timesteps  | 988042   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0362   |
# |    n_updates        | 244510   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10588    |
# |    fps              | 166      |
# |    time_elapsed     | 5929     |
# |    total_timesteps  | 988502   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0322   |
# |    n_updates        | 244625   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10592    |
# |    fps              | 166      |
# |    time_elapsed     | 5932     |
# |    total_timesteps  | 988933   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0443   |
# |    n_updates        | 244733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10596    |
# |    fps              | 166      |
# |    time_elapsed     | 5934     |
# |    total_timesteps  | 989315   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0448   |
# |    n_updates        | 244828   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10600    |
# |    fps              | 166      |
# |    time_elapsed     | 5937     |
# |    total_timesteps  | 989840   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0331   |
# |    n_updates        | 244959   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10604    |
# |    fps              | 166      |
# |    time_elapsed     | 5941     |
# |    total_timesteps  | 990379   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0863   |
# |    n_updates        | 245094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10608    |
# |    fps              | 166      |
# |    time_elapsed     | 5944     |
# |    total_timesteps  | 990929   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0724   |
# |    n_updates        | 245232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10612    |
# |    fps              | 166      |
# |    time_elapsed     | 5947     |
# |    total_timesteps  | 991448   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0523   |
# |    n_updates        | 245361   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10616    |
# |    fps              | 166      |
# |    time_elapsed     | 5950     |
# |    total_timesteps  | 991928   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0295   |
# |    n_updates        | 245481   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10620    |
# |    fps              | 166      |
# |    time_elapsed     | 5953     |
# |    total_timesteps  | 992355   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0418   |
# |    n_updates        | 245588   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10624    |
# |    fps              | 166      |
# |    time_elapsed     | 5956     |
# |    total_timesteps  | 992868   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0984   |
# |    n_updates        | 245716   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10628    |
# |    fps              | 166      |
# |    time_elapsed     | 5959     |
# |    total_timesteps  | 993479   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0383   |
# |    n_updates        | 245869   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10632    |
# |    fps              | 166      |
# |    time_elapsed     | 5962     |
# |    total_timesteps  | 993899   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0567   |
# |    n_updates        | 245974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10636    |
# |    fps              | 166      |
# |    time_elapsed     | 5964     |
# |    total_timesteps  | 994323   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0287   |
# |    n_updates        | 246080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10640    |
# |    fps              | 166      |
# |    time_elapsed     | 5968     |
# |    total_timesteps  | 994892   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0362   |
# |    n_updates        | 246222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10644    |
# |    fps              | 166      |
# |    time_elapsed     | 5970     |
# |    total_timesteps  | 995222   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0389   |
# |    n_updates        | 246305   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10648    |
# |    fps              | 166      |
# |    time_elapsed     | 5972     |
# |    total_timesteps  | 995645   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0348   |
# |    n_updates        | 246411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10652    |
# |    fps              | 166      |
# |    time_elapsed     | 5974     |
# |    total_timesteps  | 995969   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0253   |
# |    n_updates        | 246492   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10656    |
# |    fps              | 166      |
# |    time_elapsed     | 5977     |
# |    total_timesteps  | 996500   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0413   |
# |    n_updates        | 246624   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10660    |
# |    fps              | 166      |
# |    time_elapsed     | 5980     |
# |    total_timesteps  | 996991   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0488   |
# |    n_updates        | 246747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10664    |
# |    fps              | 166      |
# |    time_elapsed     | 5983     |
# |    total_timesteps  | 997446   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0214   |
# |    n_updates        | 246861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10668    |
# |    fps              | 166      |
# |    time_elapsed     | 5986     |
# |    total_timesteps  | 997922   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0328   |
# |    n_updates        | 246980   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10672    |
# |    fps              | 166      |
# |    time_elapsed     | 5987     |
# |    total_timesteps  | 998162   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0491   |
# |    n_updates        | 247040   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10676    |
# |    fps              | 166      |
# |    time_elapsed     | 5990     |
# |    total_timesteps  | 998638   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0302   |
# |    n_updates        | 247159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10680    |
# |    fps              | 166      |
# |    time_elapsed     | 5992     |
# |    total_timesteps  | 999063   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0438   |
# |    n_updates        | 247265   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10684    |
# |    fps              | 166      |
# |    time_elapsed     | 5995     |
# |    total_timesteps  | 999428   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0689   |
# |    n_updates        | 247356   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10688    |
# |    fps              | 166      |
# |    time_elapsed     | 5997     |
# |    total_timesteps  | 999886   |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0335   |
# |    n_updates        | 247471   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=10.40 +/- 8.14
# Episode length: 76.40 +/- 51.90
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 76.4     |
# |    mean_reward      | 10.4     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0002   |
# |    loss             | 0.0474   |
# |    n_updates        | 247499   |
# ----------------------------------
#
# Model saved -> /kaggle/working/kerie/runs/exp6_faster_decay/dqn_model.zip

# %%
eval_npz = os.path.join(eval_dir, 'evaluations.npz')
if os.path.isfile(eval_npz):
    data = np.load(eval_npz)
    timesteps = data['timesteps']
    mean_rewards = data['results'].mean(axis=1)
    std_rewards = data['results'].std(axis=1)

    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, mean_rewards, label='Mean Reward')
    plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3, label='Std Dev')
    plt.xlabel('Timesteps')
    plt.ylabel('Eval Reward')
    plt.title(f'Exp {EXP_ID:02d}: {EXP_NAME}\nlr={LR} gamma={GAMMA} batch={BATCH_SIZE} eps_frac={EPS_FRAC}')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'reward_plot.png'), dpi=150)
    plt.show()

    csv_path = os.path.join(OUTPUT_DIR, 'results.csv')
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['timestep', 'mean_reward', 'std_reward'])
        for t, m, s in zip(timesteps, mean_rewards, std_rewards):
            writer.writerow([int(t), f'{m:.2f}', f'{s:.2f}'])

    print(f'Best reward: {mean_rewards.max():.1f}')
    print(f'Final reward: {mean_rewards[-1]:.1f}')
    print(f'\nDownload outputs from the Output tab ->')
# Out:
# Best reward: 39.8
# Final reward: 10.4
#
# Download outputs from the Output tab ->
