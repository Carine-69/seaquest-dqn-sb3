# %% [markdown]
# # Seaquest DQN — Exp 7: exp7_slower_decay
# **1M steps from scratch** | CnnPolicy | ALE/Seaquest-v5

# %%
import subprocess, sys

# Reinstall PyTorch with correct CUDA version for this Kaggle GPU
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
    'torch', 'torchvision', '--index-url', 'https://download.pytorch.org/whl/cu121'])

for pkg in ['ale-py', 'gymnasium[atari]', 'stable-baselines3', 'opencv-python']:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pkg])
print('All packages installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 4.6 MB/s eta 0:00:00
# All packages installed.

# %%
import os, csv, gc
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import ale_py
import torch
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import EvalCallback
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# 2026-03-22 09:06:40.142363: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774170400.596407      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774170400.720691      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774170401.793961      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774170401.794004      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774170401.794007      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774170401.794009      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# CUDA available: True
# GPU: Tesla T4

# %%
EXP_ID = 7
EXP_NAME = 'exp7_slower_decay'
LR = 0.0001
GAMMA = 0.94
BATCH_SIZE = 64
EPS_START = 1.0
EPS_END = 0.05
EPS_FRAC = 0.25
NOTES = 'Slower decay — prolonged exploration'

ENV_ID = 'ALE/Seaquest-v5'
TOTAL_TIMESTEPS = 1_000_000
BUFFER_SIZE = 50_000
LEARNING_STARTS = 10_000
TARGET_UPDATE = 1_000
N_STACK = 4
OUTPUT_DIR = f'/kaggle/working/kerie/runs/{EXP_NAME}'

print(f'Exp {EXP_ID}: {EXP_NAME}')
print(f'Steps: {TOTAL_TIMESTEPS:,}')
print(f'lr={LR} gamma={GAMMA} batch={BATCH_SIZE}')
print(f'eps: {EPS_START} -> {EPS_END} over {EPS_FRAC} of training')
# Out:
# Exp 7: exp7_slower_decay
# Steps: 1,000,000
# lr=0.0001 gamma=0.94 batch=64
# eps: 1.0 -> 0.05 over 0.25 of training

# %%
def make_env(render_mode=None):
    def _init():
        env = gym.make(ENV_ID, render_mode=render_mode)
        env = AtariWrapper(env)
        return env
    vec_env = DummyVecEnv([_init])
    vec_env = VecFrameStack(vec_env, n_stack=N_STACK)
    return vec_env

log_dir = os.path.join(OUTPUT_DIR, 'tensorboard')
eval_dir = os.path.join(OUTPUT_DIR, 'eval')
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

train_env = make_env()
eval_env = make_env()

# optimize_memory_usage: avoids storing next_state twice in replay buffer (~50% less RAM)
# handle_timeout_termination=False required when optimize_memory_usage=True
# Safe for Atari — AtariWrapper handles episode boundaries via life-loss detection
model = DQN(
    policy='CnnPolicy',
    env=train_env,
    learning_rate=LR,
    gamma=GAMMA,
    batch_size=BATCH_SIZE,
    exploration_initial_eps=EPS_START,
    exploration_final_eps=EPS_END,
    exploration_fraction=EPS_FRAC,
    buffer_size=BUFFER_SIZE,
    learning_starts=LEARNING_STARTS,
    target_update_interval=TARGET_UPDATE,
    tensorboard_log=log_dir,
    verbose=1,
    optimize_memory_usage=True,
    replay_buffer_kwargs={'handle_timeout_termination': False},
)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=eval_dir,
    log_path=eval_dir,
    eval_freq=25_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=eval_callback,
    tb_log_name=EXP_NAME,
    reset_num_timesteps=True,
)

model.save(os.path.join(OUTPUT_DIR, 'dqn_model'))
print(f'\nModel saved -> {OUTPUT_DIR}/dqn_model.zip')

train_env.close()
eval_env.close()
del model
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00854  |
# |    n_updates        | 887      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 260      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 13659    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00875  |
# ...
# | time/               |          |
# |    episodes         | 13072    |
# |    fps              | 175      |
# |    time_elapsed     | 5613     |
# |    total_timesteps  | 983320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 243329   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13076    |
# |    fps              | 175      |
# |    time_elapsed     | 5615     |
# |    total_timesteps  | 983788   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0336   |
# |    n_updates        | 243446   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13080    |
# |    fps              | 175      |
# |    time_elapsed     | 5618     |
# |    total_timesteps  | 984329   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0306   |
# |    n_updates        | 243582   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13084    |
# |    fps              | 175      |
# |    time_elapsed     | 5622     |
# |    total_timesteps  | 985037   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 243759   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13088    |
# |    fps              | 175      |
# |    time_elapsed     | 5625     |
# |    total_timesteps  | 985512   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0449   |
# |    n_updates        | 243877   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13092    |
# |    fps              | 175      |
# |    time_elapsed     | 5627     |
# |    total_timesteps  | 985999   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 243999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13096    |
# |    fps              | 175      |
# |    time_elapsed     | 5630     |
# |    total_timesteps  | 986560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.068    |
# |    n_updates        | 244139   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13100    |
# |    fps              | 175      |
# |    time_elapsed     | 5633     |
# |    total_timesteps  | 987017   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 244254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13104    |
# |    fps              | 175      |
# |    time_elapsed     | 5635     |
# |    total_timesteps  | 987470   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.147    |
# |    n_updates        | 244367   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13108    |
# |    fps              | 175      |
# |    time_elapsed     | 5638     |
# |    total_timesteps  | 987953   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0697   |
# |    n_updates        | 244488   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13112    |
# |    fps              | 175      |
# |    time_elapsed     | 5642     |
# |    total_timesteps  | 988636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 244658   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13116    |
# |    fps              | 175      |
# |    time_elapsed     | 5646     |
# |    total_timesteps  | 989283   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0754   |
# |    n_updates        | 244820   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13120    |
# |    fps              | 175      |
# |    time_elapsed     | 5648     |
# |    total_timesteps  | 989728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0884   |
# |    n_updates        | 244931   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13124    |
# |    fps              | 175      |
# |    time_elapsed     | 5650     |
# |    total_timesteps  | 990020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0684   |
# |    n_updates        | 245004   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13128    |
# |    fps              | 175      |
# |    time_elapsed     | 5651     |
# |    total_timesteps  | 990267   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 245066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13132    |
# |    fps              | 175      |
# |    time_elapsed     | 5654     |
# |    total_timesteps  | 990880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.074    |
# |    n_updates        | 245219   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13136    |
# |    fps              | 175      |
# |    time_elapsed     | 5658     |
# |    total_timesteps  | 991582   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 245395   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13140    |
# |    fps              | 175      |
# |    time_elapsed     | 5661     |
# |    total_timesteps  | 992019   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0656   |
# |    n_updates        | 245504   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13144    |
# |    fps              | 175      |
# |    time_elapsed     | 5664     |
# |    total_timesteps  | 992668   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0327   |
# |    n_updates        | 245666   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13148    |
# |    fps              | 175      |
# |    time_elapsed     | 5667     |
# |    total_timesteps  | 993157   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0683   |
# |    n_updates        | 245789   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13152    |
# |    fps              | 175      |
# |    time_elapsed     | 5670     |
# |    total_timesteps  | 993769   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0638   |
# |    n_updates        | 245942   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13156    |
# |    fps              | 175      |
# |    time_elapsed     | 5673     |
# |    total_timesteps  | 994206   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0392   |
# |    n_updates        | 246051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13160    |
# |    fps              | 175      |
# |    time_elapsed     | 5676     |
# |    total_timesteps  | 994694   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0937   |
# |    n_updates        | 246173   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13164    |
# |    fps              | 175      |
# |    time_elapsed     | 5677     |
# |    total_timesteps  | 995035   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0422   |
# |    n_updates        | 246258   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13168    |
# |    fps              | 175      |
# |    time_elapsed     | 5679     |
# |    total_timesteps  | 995329   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0696   |
# |    n_updates        | 246332   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13172    |
# |    fps              | 175      |
# |    time_elapsed     | 5682     |
# |    total_timesteps  | 995833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0916   |
# |    n_updates        | 246458   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13176    |
# |    fps              | 175      |
# |    time_elapsed     | 5685     |
# |    total_timesteps  | 996416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0873   |
# |    n_updates        | 246603   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13180    |
# |    fps              | 175      |
# |    time_elapsed     | 5688     |
# |    total_timesteps  | 996943   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 246735   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13184    |
# |    fps              | 175      |
# |    time_elapsed     | 5690     |
# |    total_timesteps  | 997248   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 246811   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13188    |
# |    fps              | 175      |
# |    time_elapsed     | 5693     |
# |    total_timesteps  | 997784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0436   |
# |    n_updates        | 246945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13192    |
# |    fps              | 175      |
# |    time_elapsed     | 5695     |
# |    total_timesteps  | 998141   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0414   |
# |    n_updates        | 247035   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13196    |
# |    fps              | 175      |
# |    time_elapsed     | 5697     |
# |    total_timesteps  | 998521   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0568   |
# |    n_updates        | 247130   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13200    |
# |    fps              | 175      |
# |    time_elapsed     | 5701     |
# |    total_timesteps  | 999186   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0636   |
# |    n_updates        | 247296   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13204    |
# |    fps              | 175      |
# |    time_elapsed     | 5704     |
# |    total_timesteps  | 999744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 247435   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=32.80 +/- 11.60
# Episode length: 141.60 +/- 36.57
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 142      |
# |    mean_reward      | 32.8     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 247499   |
# ----------------------------------
#
# Model saved -> /kaggle/working/kerie/runs/exp7_slower_decay/dqn_model.zip

# %%
eval_npz = os.path.join(eval_dir, 'evaluations.npz')
if os.path.isfile(eval_npz):
    data = np.load(eval_npz)
    timesteps = data['timesteps']
    mean_rewards = data['results'].mean(axis=1)
    std_rewards = data['results'].std(axis=1)

    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, mean_rewards, label='Mean Reward')
    plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3, label='Std Dev')
    plt.xlabel('Timesteps')
    plt.ylabel('Eval Reward')
    plt.title(f'Exp {EXP_ID:02d}: {EXP_NAME}\nlr={LR} gamma={GAMMA} batch={BATCH_SIZE} eps_frac={EPS_FRAC}')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'reward_plot.png'), dpi=150)
    plt.show()

    csv_path = os.path.join(OUTPUT_DIR, 'results.csv')
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['timestep', 'mean_reward', 'std_reward'])
        for t, m, s in zip(timesteps, mean_rewards, std_rewards):
            writer.writerow([int(t), f'{m:.2f}', f'{s:.2f}'])

    print(f'Best reward: {mean_rewards.max():.1f}')
    print(f'Final reward: {mean_rewards[-1]:.1f}')
    print(f'\nDownload outputs from the Output tab ->')
# Out:
# Best reward: 45.8
# Final reward: 32.8
#
# Download outputs from the Output tab ->
