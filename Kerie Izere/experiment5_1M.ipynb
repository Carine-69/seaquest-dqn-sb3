# %% [markdown]
# # Seaquest DQN — Exp 5: exp5_lower_eps_end
# **1M steps from scratch** | CnnPolicy | ALE/Seaquest-v5

# %%
import subprocess, sys

# Reinstall PyTorch with correct CUDA version for this Kaggle GPU
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
    'torch', 'torchvision', '--index-url', 'https://download.pytorch.org/whl/cu121'])

for pkg in ['ale-py', 'gymnasium[atari]', 'stable-baselines3', 'opencv-python']:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pkg])
print('All packages installed.')
# Out:
# All packages installed.

# %%
import os, csv, gc
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import ale_py
import torch
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import EvalCallback
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
EXP_ID = 5
EXP_NAME = 'exp5_lower_eps_end'
LR = 0.0001
GAMMA = 0.96
BATCH_SIZE = 64
EPS_START = 1.0
EPS_END = 0.02
EPS_FRAC = 0.10
NOTES = 'Lower eps_end — more greedy late stage'

ENV_ID = 'ALE/Seaquest-v5'
TOTAL_TIMESTEPS = 1_000_000
BUFFER_SIZE = 50_000
LEARNING_STARTS = 10_000
TARGET_UPDATE = 1_000
N_STACK = 4
OUTPUT_DIR = f'/kaggle/working/kerie/runs/{EXP_NAME}'

print(f'Exp {EXP_ID}: {EXP_NAME}')
print(f'Steps: {TOTAL_TIMESTEPS:,}')
print(f'lr={LR} gamma={GAMMA} batch={BATCH_SIZE}')
print(f'eps: {EPS_START} -> {EPS_END} over {EPS_FRAC} of training')
# Out:
# Exp 5: exp5_lower_eps_end
# Steps: 1,000,000
# lr=0.0001 gamma=0.96 batch=64
# eps: 1.0 -> 0.02 over 0.1 of training

# %%
def make_env(render_mode=None):
    def _init():
        env = gym.make(ENV_ID, render_mode=render_mode)
        env = AtariWrapper(env)
        return env
    vec_env = DummyVecEnv([_init])
    vec_env = VecFrameStack(vec_env, n_stack=N_STACK)
    return vec_env

log_dir = os.path.join(OUTPUT_DIR, 'tensorboard')
eval_dir = os.path.join(OUTPUT_DIR, 'eval')
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

train_env = make_env()
eval_env = make_env()

# optimize_memory_usage: avoids storing next_state twice in replay buffer (~50% less RAM)
# handle_timeout_termination=False required when optimize_memory_usage=True
# Safe for Atari — AtariWrapper handles episode boundaries via life-loss detection
model = DQN(
    policy='CnnPolicy',
    env=train_env,
    learning_rate=LR,
    gamma=GAMMA,
    batch_size=BATCH_SIZE,
    exploration_initial_eps=EPS_START,
    exploration_final_eps=EPS_END,
    exploration_fraction=EPS_FRAC,
    buffer_size=BUFFER_SIZE,
    learning_starts=LEARNING_STARTS,
    target_update_interval=TARGET_UPDATE,
    tensorboard_log=log_dir,
    verbose=1,
    optimize_memory_usage=True,
    replay_buffer_kwargs={'handle_timeout_termination': False},
)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=eval_dir,
    log_path=eval_dir,
    eval_freq=25_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=eval_callback,
    tb_log_name=EXP_NAME,
    reset_num_timesteps=True,
)

model.save(os.path.join(OUTPUT_DIR, 'dqn_model'))
print(f'\nModel saved -> {OUTPUT_DIR}/dqn_model.zip')

train_env.close()
eval_env.close()
del model
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to /kaggle/working/kerie/runs/exp5_lower_eps_end/tensorboard/exp5_lower_eps_end_1
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7abe4e700b30> != <stable_baselines3.common.vec_env.vec_frame_stack.VecFrameStack object at 0x7abe4e7d71a0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 254      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 269      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 210      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 279      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 325      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 284      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 283      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 286      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 625      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 289      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 768      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 290      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 862      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 289      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 943      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 288      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 287      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 289      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 288      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 288      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 288      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 288      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 288      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 288      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1818     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 288      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 289      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 288      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 288      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2170     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 289      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 289      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 288      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 288      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 288      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 288      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 288      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 288      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 2900     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 289      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 289      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 289      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 289      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 289      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 289      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3503     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 288      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 288      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 288      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3811     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 288      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 288      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 288      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 288      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 287      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 287      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4335     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 287      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 288      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 287      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 4611     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 287      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 4726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 287      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 4821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 287      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 4941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 288      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 5062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 288      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 288      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 288      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 288      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 288      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 5607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 289      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 5747     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 289      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 5860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 289      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 5948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 289      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 6018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 289      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 289      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 288      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 288      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 288      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 288      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 288      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 288      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 288      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 288      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 6984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 288      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 7074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 288      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 7155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 288      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 288      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 288      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 288      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 288      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 288      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 287      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 7848     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 288      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 7974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 288      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 8038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 287      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 288      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 287      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8335     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 287      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 287      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 287      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 287      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 287      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 287      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 287      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8910     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 287      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 288      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9110     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 288      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 288      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 288      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 9562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 288      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 9707     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 288      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 9791     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 288      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 9881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 288      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 9965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 287      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 10055    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 286      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 10164    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00838  |
# |    n_updates        | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 285      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 10272    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 283      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 10349    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 87       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 282      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 10477    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 119      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 280      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 10625    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00822  |
# |    n_updates        | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 278      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 10758    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00747  |
# |    n_updates        | 189      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 277      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 10832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00837  |
# |    n_updates        | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 276      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 10985    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000778 |
# |    n_updates        | 246      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 274      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 11090    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00804  |
# |    n_updates        | 272      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 273      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 11186    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00122  |
# |    n_updates        | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 272      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 11294    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00753  |
# |    n_updates        | 323      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 271      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 11408    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 270      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 11542    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 385      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 268      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 11700    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 424      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 267      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 11806    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00754  |
# |    n_updates        | 451      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 266      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 11865    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00397  |
# |    n_updates        | 466      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 265      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 11979    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 494      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 264      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 12134    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000912 |
# |    n_updates        | 533      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 263      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 12231    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00155  |
# |    n_updates        | 557      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 263      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 12317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 579      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 262      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 12411    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00836  |
# |    n_updates        | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 261      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 12530    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 632      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 260      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 12630    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 657      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 260      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 12717    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 679      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 259      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 12774    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 259      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 12884    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 720      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 258      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 12953    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00821  |
# |    n_updates        | 738      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 257      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 13051    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 762      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 256      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 13204    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0423   |
# |    n_updates        | 800      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 256      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 13285    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 821      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 255      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 13515    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 878      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 254      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 13610    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 902      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 253      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 13724    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 930      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.864    |
# ...
# | time/               |          |
# |    episodes         | 10052    |
# |    fps              | 168      |
# |    time_elapsed     | 5842     |
# |    total_timesteps  | 984155   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 243538   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10056    |
# |    fps              | 168      |
# |    time_elapsed     | 5844     |
# |    total_timesteps  | 984590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 243647   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10060    |
# |    fps              | 168      |
# |    time_elapsed     | 5847     |
# |    total_timesteps  | 985095   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 243773   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10064    |
# |    fps              | 168      |
# |    time_elapsed     | 5850     |
# |    total_timesteps  | 985493   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 243873   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10068    |
# |    fps              | 168      |
# |    time_elapsed     | 5852     |
# |    total_timesteps  | 985944   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 243985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10072    |
# |    fps              | 168      |
# |    time_elapsed     | 5856     |
# |    total_timesteps  | 986497   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00882  |
# |    n_updates        | 244124   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10076    |
# |    fps              | 168      |
# |    time_elapsed     | 5858     |
# |    total_timesteps  | 986923   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 244230   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10080    |
# |    fps              | 168      |
# |    time_elapsed     | 5861     |
# |    total_timesteps  | 987475   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 244368   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10084    |
# |    fps              | 168      |
# |    time_elapsed     | 5865     |
# |    total_timesteps  | 988020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 244504   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10088    |
# |    fps              | 168      |
# |    time_elapsed     | 5868     |
# |    total_timesteps  | 988571   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 244642   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10092    |
# |    fps              | 168      |
# |    time_elapsed     | 5870     |
# |    total_timesteps  | 989034   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 244758   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10096    |
# |    fps              | 168      |
# |    time_elapsed     | 5873     |
# |    total_timesteps  | 989535   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 244883   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10100    |
# |    fps              | 168      |
# |    time_elapsed     | 5877     |
# |    total_timesteps  | 990088   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 245021   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10104    |
# |    fps              | 168      |
# |    time_elapsed     | 5878     |
# |    total_timesteps  | 990299   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 245074   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10108    |
# |    fps              | 168      |
# |    time_elapsed     | 5881     |
# |    total_timesteps  | 990748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 245186   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10112    |
# |    fps              | 168      |
# |    time_elapsed     | 5884     |
# |    total_timesteps  | 991281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 245320   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10116    |
# |    fps              | 168      |
# |    time_elapsed     | 5887     |
# |    total_timesteps  | 991832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 245457   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10120    |
# |    fps              | 168      |
# |    time_elapsed     | 5889     |
# |    total_timesteps  | 992250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 245562   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10124    |
# |    fps              | 168      |
# |    time_elapsed     | 5891     |
# |    total_timesteps  | 992544   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 245635   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10128    |
# |    fps              | 168      |
# |    time_elapsed     | 5894     |
# |    total_timesteps  | 993058   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 245764   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10132    |
# |    fps              | 168      |
# |    time_elapsed     | 5897     |
# |    total_timesteps  | 993535   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 245883   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10136    |
# |    fps              | 168      |
# |    time_elapsed     | 5900     |
# |    total_timesteps  | 994007   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 246001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10140    |
# |    fps              | 168      |
# |    time_elapsed     | 5903     |
# |    total_timesteps  | 994528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 246131   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10144    |
# |    fps              | 168      |
# |    time_elapsed     | 5905     |
# |    total_timesteps  | 994949   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 246237   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10148    |
# |    fps              | 168      |
# |    time_elapsed     | 5908     |
# |    total_timesteps  | 995362   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 246340   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10152    |
# |    fps              | 168      |
# |    time_elapsed     | 5911     |
# |    total_timesteps  | 995916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 246478   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10156    |
# |    fps              | 168      |
# |    time_elapsed     | 5913     |
# |    total_timesteps  | 996213   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 246553   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10160    |
# |    fps              | 168      |
# |    time_elapsed     | 5915     |
# |    total_timesteps  | 996624   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 246655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10164    |
# |    fps              | 168      |
# |    time_elapsed     | 5919     |
# |    total_timesteps  | 997180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 246794   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10168    |
# |    fps              | 168      |
# |    time_elapsed     | 5921     |
# |    total_timesteps  | 997621   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 246905   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10172    |
# |    fps              | 168      |
# |    time_elapsed     | 5925     |
# |    total_timesteps  | 998177   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 247044   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10176    |
# |    fps              | 168      |
# |    time_elapsed     | 5928     |
# |    total_timesteps  | 998733   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 247183   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10180    |
# |    fps              | 168      |
# |    time_elapsed     | 5931     |
# |    total_timesteps  | 999207   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 247301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10184    |
# |    fps              | 168      |
# |    time_elapsed     | 5933     |
# |    total_timesteps  | 999626   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 247406   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=20.20 +/- 5.42
# Episode length: 113.80 +/- 27.04
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 114      |
# |    mean_reward      | 20.2     |
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 247499   |
# ----------------------------------
#
# Model saved -> /kaggle/working/kerie/runs/exp5_lower_eps_end/dqn_model.zip

# %%
eval_npz = os.path.join(eval_dir, 'evaluations.npz')
if os.path.isfile(eval_npz):
    data = np.load(eval_npz)
    timesteps = data['timesteps']
    mean_rewards = data['results'].mean(axis=1)
    std_rewards = data['results'].std(axis=1)

    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, mean_rewards, label='Mean Reward')
    plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3, label='Std Dev')
    plt.xlabel('Timesteps')
    plt.ylabel('Eval Reward')
    plt.title(f'Exp {EXP_ID:02d}: {EXP_NAME}\nlr={LR} gamma={GAMMA} batch={BATCH_SIZE} eps_frac={EPS_FRAC}')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'reward_plot.png'), dpi=150)
    plt.show()

    csv_path = os.path.join(OUTPUT_DIR, 'results.csv')
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['timestep', 'mean_reward', 'std_reward'])
        for t, m, s in zip(timesteps, mean_rewards, std_rewards):
            writer.writerow([int(t), f'{m:.2f}', f'{s:.2f}'])

    print(f'Best reward: {mean_rewards.max():.1f}')
    print(f'Final reward: {mean_rewards[-1]:.1f}')
    print(f'\nDownload outputs from the Output tab ->')
# Out:
# Best reward: 22.6
# Final reward: 20.2
#
# Download outputs from the Output tab ->
