# %% [markdown]
# # Seaquest DQN — Exp 4: exp4_lower_eps_start
# **1M steps from scratch** | CnnPolicy | ALE/Seaquest-v5

# %%
import subprocess, sys

# Reinstall PyTorch with correct CUDA version for this Kaggle GPU
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
    'torch', 'torchvision', '--index-url', 'https://download.pytorch.org/whl/cu121'])

for pkg in ['ale-py', 'gymnasium[atari]', 'stable-baselines3', 'opencv-python']:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pkg])
print('All packages installed.')
# Out:
# All packages installed.

# %%
import os, csv, gc
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import ale_py
import torch
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import EvalCallback
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
EXP_ID = 4
EXP_NAME = 'exp4_lower_eps_start'
LR = 0.0003
GAMMA = 0.94
BATCH_SIZE = 64
EPS_START = 0.9
EPS_END = 0.05
EPS_FRAC = 0.10
NOTES = 'Lower eps_start — less initial randomness'

ENV_ID = 'ALE/Seaquest-v5'
TOTAL_TIMESTEPS = 1_000_000
BUFFER_SIZE = 50_000
LEARNING_STARTS = 10_000
TARGET_UPDATE = 1_000
N_STACK = 4
OUTPUT_DIR = f'/kaggle/working/kerie/runs/{EXP_NAME}'

print(f'Exp {EXP_ID}: {EXP_NAME}')
print(f'Steps: {TOTAL_TIMESTEPS:,}')
print(f'lr={LR} gamma={GAMMA} batch={BATCH_SIZE}')
print(f'eps: {EPS_START} -> {EPS_END} over {EPS_FRAC} of training')
# Out:
# Exp 4: exp4_lower_eps_start
# Steps: 1,000,000
# lr=0.0003 gamma=0.94 batch=64
# eps: 0.9 -> 0.05 over 0.1 of training

# %%
def make_env(render_mode=None):
    def _init():
        env = gym.make(ENV_ID, render_mode=render_mode)
        env = AtariWrapper(env)
        return env
    vec_env = DummyVecEnv([_init])
    vec_env = VecFrameStack(vec_env, n_stack=N_STACK)
    return vec_env

log_dir = os.path.join(OUTPUT_DIR, 'tensorboard')
eval_dir = os.path.join(OUTPUT_DIR, 'eval')
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

train_env = make_env()
eval_env = make_env()

# optimize_memory_usage: avoids storing next_state twice in replay buffer (~50% less RAM)
# handle_timeout_termination=False required when optimize_memory_usage=True
# Safe for Atari — AtariWrapper handles episode boundaries via life-loss detection
model = DQN(
    policy='CnnPolicy',
    env=train_env,
    learning_rate=LR,
    gamma=GAMMA,
    batch_size=BATCH_SIZE,
    exploration_initial_eps=EPS_START,
    exploration_final_eps=EPS_END,
    exploration_fraction=EPS_FRAC,
    buffer_size=BUFFER_SIZE,
    learning_starts=LEARNING_STARTS,
    target_update_interval=TARGET_UPDATE,
    tensorboard_log=log_dir,
    verbose=1,
    optimize_memory_usage=True,
    replay_buffer_kwargs={'handle_timeout_termination': False},
)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=eval_dir,
    log_path=eval_dir,
    eval_freq=25_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=eval_callback,
    tb_log_name=EXP_NAME,
    reset_num_timesteps=True,
)

model.save(os.path.join(OUTPUT_DIR, 'dqn_model'))
print(f'\nModel saved -> {OUTPUT_DIR}/dqn_model.zip')

train_env.close()
eval_env.close()
del model
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to /kaggle/working/kerie/runs/exp4_lower_eps_start/tensorboard/exp4_lower_eps_start_1
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7abe4e770b90> != <stable_baselines3.common.vec_env.vec_frame_stack.VecFrameStack object at 0x7abf2082ede0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 286      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 130      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 291      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 291      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 348      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 289      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 421      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 294      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 563      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 291      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 660      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 286      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 744      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 287      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 879      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 287      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 987      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 285      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 287      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 286      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 285      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1386     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 286      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 286      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 286      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 286      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 288      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 287      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 288      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 288      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 289      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2387     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 289      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 290      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 290      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 290      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 290      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 2920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 290      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 290      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 290      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 290      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 290      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3416     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 290      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 290      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 289      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 289      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 289      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 289      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 3989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 289      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 4046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 289      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 289      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 4248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 289      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 289      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 289      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 289      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 4651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 289      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 4753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 290      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 4856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 290      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 4970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 290      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 5135     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 290      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 5222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 290      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 290      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 5415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 290      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 5524     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 290      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 5630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 290      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 5748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 290      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 5815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 290      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 5946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 290      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 6032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 290      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 291      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 291      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 6381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 291      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 291      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6568     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 291      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6661     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 291      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 291      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6818     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 290      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 290      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 7008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 290      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 7100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 290      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 7196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 290      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 290      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 290      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 7485     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 290      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7580     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 290      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 290      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 7768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 290      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 7848     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 290      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 7950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 290      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 8035     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 290      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 290      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 290      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 8357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 290      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 290      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 290      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 290      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8722     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 290      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 290      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 8936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 290      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 290      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9132     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 290      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 9207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 290      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 290      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 290      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 290      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 9583     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 290      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 9671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 290      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 9817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 290      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 9890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 290      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 10017    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.015    |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 289      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 10091    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0158   |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 288      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 10172    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0226   |
# |    n_updates        | 42       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 286      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 10270    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00828  |
# |    n_updates        | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 285      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 10362    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00777  |
# |    n_updates        | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 283      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 10472    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00784  |
# |    n_updates        | 117      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 282      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 10564    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.000615 |
# |    n_updates        | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 279      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 10760    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00136  |
# |    n_updates        | 189      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 278      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 10844    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00755  |
# |    n_updates        | 210      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 277      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 10975    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0143   |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 275      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 11080    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0217   |
# |    n_updates        | 269      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 273      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 11254    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.023    |
# |    n_updates        | 313      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 273      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 11326    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00811  |
# |    n_updates        | 331      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 272      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 11398    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0588   |
# |    n_updates        | 349      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 271      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 11482    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0218   |
# |    n_updates        | 370      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 269      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 11615    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0308   |
# |    n_updates        | 403      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 268      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 11741    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00881  |
# |    n_updates        | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 267      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 11838    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0295   |
# |    n_updates        | 459      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 266      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 11948    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0142   |
# |    n_updates        | 486      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 265      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 12052    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0135   |
# |    n_updates        | 512      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 264      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 12138    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00799  |
# |    n_updates        | 534      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 263      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 12262    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0164   |
# |    n_updates        | 565      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 262      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 12402    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0322   |
# |    n_updates        | 600      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 262      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 12467    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00894  |
# |    n_updates        | 616      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 261      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 12618    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0157   |
# |    n_updates        | 654      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 260      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 12741    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0238   |
# |    n_updates        | 685      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 259      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 12846    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00436  |
# |    n_updates        | 711      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 258      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 12929    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00701  |
# |    n_updates        | 732      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 258      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 13013    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0223   |
# |    n_updates        | 753      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 257      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 13127    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00522  |
# |    n_updates        | 781      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 256      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 13237    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00667  |
# |    n_updates        | 809      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 256      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 13340    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0211   |
# |    n_updates        | 834      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 255      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 13429    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.00764  |
# |    n_updates        | 857      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 254      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 13534    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0125   |
# |    n_updates        | 883      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 254      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 13642    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0167   |
# |    n_updates        | 910      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 253      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 13783    |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0119   |
# |    n_updates        | 945      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.782    |
# | time/               |          |
# ...
# | time/               |          |
# |    episodes         | 12868    |
# |    fps              | 169      |
# |    time_elapsed     | 5838     |
# |    total_timesteps  | 987517   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.093    |
# |    n_updates        | 244379   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12872    |
# |    fps              | 169      |
# |    time_elapsed     | 5840     |
# |    total_timesteps  | 987817   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.026    |
# |    n_updates        | 244454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12876    |
# |    fps              | 169      |
# |    time_elapsed     | 5842     |
# |    total_timesteps  | 988091   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0232   |
# |    n_updates        | 244522   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12880    |
# |    fps              | 169      |
# |    time_elapsed     | 5844     |
# |    total_timesteps  | 988496   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0226   |
# |    n_updates        | 244623   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12884    |
# |    fps              | 169      |
# |    time_elapsed     | 5846     |
# |    total_timesteps  | 988842   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0305   |
# |    n_updates        | 244710   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12888    |
# |    fps              | 169      |
# |    time_elapsed     | 5848     |
# |    total_timesteps  | 989160   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0243   |
# |    n_updates        | 244789   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12892    |
# |    fps              | 169      |
# |    time_elapsed     | 5850     |
# |    total_timesteps  | 989530   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0227   |
# |    n_updates        | 244882   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12896    |
# |    fps              | 169      |
# |    time_elapsed     | 5852     |
# |    total_timesteps  | 989831   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0268   |
# |    n_updates        | 244957   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12900    |
# |    fps              | 169      |
# |    time_elapsed     | 5855     |
# |    total_timesteps  | 990289   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0274   |
# |    n_updates        | 245072   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12904    |
# |    fps              | 169      |
# |    time_elapsed     | 5857     |
# |    total_timesteps  | 990749   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0495   |
# |    n_updates        | 245187   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12908    |
# |    fps              | 169      |
# |    time_elapsed     | 5860     |
# |    total_timesteps  | 991176   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0303   |
# |    n_updates        | 245293   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12912    |
# |    fps              | 169      |
# |    time_elapsed     | 5862     |
# |    total_timesteps  | 991509   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0374   |
# |    n_updates        | 245377   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12916    |
# |    fps              | 169      |
# |    time_elapsed     | 5864     |
# |    total_timesteps  | 991877   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0336   |
# |    n_updates        | 245469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12920    |
# |    fps              | 169      |
# |    time_elapsed     | 5865     |
# |    total_timesteps  | 992064   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0251   |
# |    n_updates        | 245515   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12924    |
# |    fps              | 169      |
# |    time_elapsed     | 5867     |
# |    total_timesteps  | 992395   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0578   |
# |    n_updates        | 245598   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12928    |
# |    fps              | 169      |
# |    time_elapsed     | 5870     |
# |    total_timesteps  | 992871   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0319   |
# |    n_updates        | 245717   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12932    |
# |    fps              | 169      |
# |    time_elapsed     | 5873     |
# |    total_timesteps  | 993298   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0353   |
# |    n_updates        | 245824   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12936    |
# |    fps              | 169      |
# |    time_elapsed     | 5875     |
# |    total_timesteps  | 993749   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0304   |
# |    n_updates        | 245937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12940    |
# |    fps              | 169      |
# |    time_elapsed     | 5877     |
# |    total_timesteps  | 994096   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0366   |
# |    n_updates        | 246023   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12944    |
# |    fps              | 169      |
# |    time_elapsed     | 5880     |
# |    total_timesteps  | 994587   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0818   |
# |    n_updates        | 246146   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12948    |
# |    fps              | 169      |
# |    time_elapsed     | 5882     |
# |    total_timesteps  | 994930   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0336   |
# |    n_updates        | 246232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12952    |
# |    fps              | 169      |
# |    time_elapsed     | 5884     |
# |    total_timesteps  | 995155   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0222   |
# |    n_updates        | 246288   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12956    |
# |    fps              | 169      |
# |    time_elapsed     | 5886     |
# |    total_timesteps  | 995576   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0241   |
# |    n_updates        | 246393   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12960    |
# |    fps              | 169      |
# |    time_elapsed     | 5888     |
# |    total_timesteps  | 995982   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0299   |
# |    n_updates        | 246495   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12964    |
# |    fps              | 169      |
# |    time_elapsed     | 5891     |
# |    total_timesteps  | 996391   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0205   |
# |    n_updates        | 246597   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12968    |
# |    fps              | 169      |
# |    time_elapsed     | 5894     |
# |    total_timesteps  | 996891   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0369   |
# |    n_updates        | 246722   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12972    |
# |    fps              | 169      |
# |    time_elapsed     | 5896     |
# |    total_timesteps  | 997281   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.118    |
# |    n_updates        | 246820   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12976    |
# |    fps              | 169      |
# |    time_elapsed     | 5898     |
# |    total_timesteps  | 997621   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0449   |
# |    n_updates        | 246905   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12980    |
# |    fps              | 169      |
# |    time_elapsed     | 5901     |
# |    total_timesteps  | 998085   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0163   |
# |    n_updates        | 247021   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12984    |
# |    fps              | 169      |
# |    time_elapsed     | 5903     |
# |    total_timesteps  | 998403   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0211   |
# |    n_updates        | 247100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12988    |
# |    fps              | 169      |
# |    time_elapsed     | 5905     |
# |    total_timesteps  | 998799   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0237   |
# |    n_updates        | 247199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12992    |
# |    fps              | 169      |
# |    time_elapsed     | 5908     |
# |    total_timesteps  | 999205   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0354   |
# |    n_updates        | 247301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12996    |
# |    fps              | 169      |
# |    time_elapsed     | 5910     |
# |    total_timesteps  | 999597   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.026    |
# |    n_updates        | 247399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 13000    |
# |    fps              | 169      |
# |    time_elapsed     | 5911     |
# |    total_timesteps  | 999843   |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0236   |
# |    n_updates        | 247460   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=22.40 +/- 15.00
# Episode length: 117.80 +/- 64.11
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 118      |
# |    mean_reward      | 22.4     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0003   |
# |    loss             | 0.0226   |
# |    n_updates        | 247499   |
# ----------------------------------
#
# Model saved -> /kaggle/working/kerie/runs/exp4_lower_eps_start/dqn_model.zip

# %%
eval_npz = os.path.join(eval_dir, 'evaluations.npz')
if os.path.isfile(eval_npz):
    data = np.load(eval_npz)
    timesteps = data['timesteps']
    mean_rewards = data['results'].mean(axis=1)
    std_rewards = data['results'].std(axis=1)

    plt.figure(figsize=(10, 5))
    plt.plot(timesteps, mean_rewards, label='Mean Reward')
    plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3, label='Std Dev')
    plt.xlabel('Timesteps')
    plt.ylabel('Eval Reward')
    plt.title(f'Exp {EXP_ID:02d}: {EXP_NAME}\nlr={LR} gamma={GAMMA} batch={BATCH_SIZE} eps_frac={EPS_FRAC}')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(OUTPUT_DIR, 'reward_plot.png'), dpi=150)
    plt.show()

    csv_path = os.path.join(OUTPUT_DIR, 'results.csv')
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['timestep', 'mean_reward', 'std_reward'])
        for t, m, s in zip(timesteps, mean_rewards, std_rewards):
            writer.writerow([int(t), f'{m:.2f}', f'{s:.2f}'])

    print(f'Best reward: {mean_rewards.max():.1f}')
    print(f'Final reward: {mean_rewards[-1]:.1f}')
    print(f'\nDownload outputs from the Output tab ->')
# Out:
# Best reward: 22.8
# Final reward: 22.4
#
# Download outputs from the Output tab ->

# %%
# !zip -r runs.zip /kaggle/working/kerie/runs
# Out:
# updating: kaggle/working/kerie/runs/exp2_lr_bump/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/tensorboard/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/tensorboard/exp2_lr_bump_1/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/tensorboard/exp2_lr_bump_1/events.out.tfevents.1774109628.014752af350c.55.0 (deflated 76%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/dqn_model.zip (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/reward_plot.png (deflated 8%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/eval/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/eval/evaluations.npz (deflated 72%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/eval/best_model.zip (stored 0%)
# updating: kaggle/working/kerie/runs/exp2_lr_bump/results.csv (deflated 48%)
# updating: kaggle/working/kerie/runs/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/tensorboard/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/tensorboard/exp3_higher_gamma_1/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/tensorboard/exp3_higher_gamma_1/events.out.tfevents.1774114589.014752af350c.55.1 (deflated 76%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/dqn_model.zip (stored 0%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/reward_plot.png (deflated 7%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/eval/ (stored 0%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/eval/evaluations.npz (deflated 74%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/eval/best_model.zip (stored 0%)
# updating: kaggle/working/kerie/runs/exp3_higher_gamma/results.csv (deflated 58%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/tensorboard/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/tensorboard/exp4_lower_eps_start_1/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/tensorboard/exp4_lower_eps_start_1/events.out.tfevents.1774121643.014752af350c.55.2 (deflated 76%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/dqn_model.zip (stored 0%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/reward_plot.png (deflated 6%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/eval/ (stored 0%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/eval/evaluations.npz (deflated 74%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/eval/best_model.zip (stored 0%)
#   adding: kaggle/working/kerie/runs/exp4_lower_eps_start/results.csv (deflated 58%)
